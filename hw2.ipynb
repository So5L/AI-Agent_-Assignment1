# %%
import openai

client = openai.OpenAI()
messages = []

# %%
def call_ai():
    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=messages,
    )
    message = response.choices[0].message.content
    messages.append({"role": "assistant", "content": message})
    print(f"AI: {message}")

# %%
while True:
    message = input("Send a message to the LLM...")
    if message == "quit" or message == "q":
        break
    else:
        messages.append({"role": "user", "content": message})
        print(f"User: {message}")
        call_ai()
# Out:
# User: 나는 SF 영화를 좋아해
# AI: SF 영화는 정말 흥미롭고 상상력을 자극하는 장르죠! 어떤 SF 영화를 특히 좋아하시나요? 또는 추천받고 싶은 영화가 있으신가요?
# User: 인셉션이랑 인터스텔라는 이미 봤어
# AI: 두 영화 다 정말 뛰어난 작품이죠! **인셉션**은 꿈과 현실의 경계를 탐구하며, **인터스텔라**는 우주 탐사와 사랑의 주제를 감동적으로 그렸습니다. 그럼 다른 SF 영화로는 어떤 걸 추천드릴까요?
#
# 1. **Blade Runner 2049 (블레이드 러너 2049)** - 인공지능과 인간성에 대한 깊은 질문을 담고 있는 후속작입니다.
# 2. **The Matrix (매트릭스)** - 가상 현실과 존재론적 질문을 다루고 있어 큰 영향을 준 작품입니다.
# 3. **Arrival (Arrival: 도착)** - 외계 생명체와의 소통을 중심으로 한 독특한 이야기입니다.
# 4. **Ex Machina (엑스 마키나)** - 인공지능의 윤리적 문제를 다룬 긴장감 넘치는 이야기입니다.
#
# 이 중에서 관심 가는 영화가 있다면 더 이야기해 볼 수 있어요!
# User: 오늘 밤에 뭐 볼지 추천해 줄래?
# AI: 물론이죠! 오늘 밤에 볼 만한 SF 영화 몇 편 추천해 드릴게요:
#
# 1. **Arrival (도착)** - 감정적이고 철학적인 요소가 가득한 외계 생명체와의 소통을 중심으로 한 이야기입니다. 언어와 시간에 대한 깊은 고찰이 흥미로워요.
#
# 2. **Annihilation (전 annihilation)** - 신비로운 지역 '셰이머'를 탐험하는 과학자들의 이야기입니다. 시각적으로 매혹적이며 복잡한 주제를 다룹니다.
#
# 3. **The Martian (마션)** - 화성에 홀로 남겨진 우주 비행사가 살아남기 위한 고군분투를 그린 영화로, 유머와 감동이 공존합니다.
#
# 4. **Snowpiercer (설국열차)** - 지구가 얼어붙은 미래에서 인류의 생존을 위해 기차가 끊임없이 돌아가는 설정에서 사회 계층과 인류애를 탐구합니다.
#
# 5. **Ghost in the Shell (공각기동대)** - 사이버펑크 세계에서 주인공이 정체성을 찾아가는 과정을 그린 애니메이션으로, 심오한 철학적 질문을 던집니다.
#
# 이 영화들 중 어떤 것이 마음에 드시나요?
# User: 내가 좋아하는 장르랑 이미 본 영화가 뭐라고 했지?
# AI: 당신은 SF 영화를 좋아한다고 하셨고, **인셉션**과 **인터스텔라**를 이미 보셨다고 말씀하셨습니다. 이 두 영화는 모두 꿈과 현실, 그리고 우주를 탐구하는 주제를 다루고 있죠. 추가로 어떤 영화를 추천해 드릴까요?
# User:
# AI: 혹시 다른 질문이나 원하는 주제가 있다면 말씀해 주세요! 추가로 추천할 영화나 SF 장르에 대해 더 이야기해드릴 수 있습니다.
# User:
# AI: 혹시 더 이야기하고 싶으신 주제나 질문이 있다면 편하게 말씀해 주세요! 저는 여기서 도와드릴 준비가 되어 있습니다.
